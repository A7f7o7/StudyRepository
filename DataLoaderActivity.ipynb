# %%
import torch
import torchvision
import matplotlib.pyplot as plt
import os
from os.path import join
from torch.utils.data import Dataset, DataLoader
from torchvision.io import read_image
import torchvision.transforms as transforms

# %%
folder = "/StudyRepository/"
mytransform = transforms.Compose([ transforms.ToTensor() ])
CIFAR10 = torchvision.datasets.CIFAR10(folder, transform=mytransform, download=True)
# Out:
# Files already downloaded and verified

# %%
def plot_batch_CIFAR10(batch_imgs, batch_labels):
    batch_size = len(batch_imgs)
    fig, axs = plt.subplots(1, batch_size, figsize=(10,5))
    for i in range(batch_size):
        axs[i].imshow(batch_imgs[i,0,:,:])
        axs[i].set_title(f"Label {batch_labels[i]}")
    plt.show()

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on {device}")

dataloader = DataLoader(CIFAR10, batch_size=5, shuffle=True)

for c_batch in dataloader:
    x, y = c_batch
    plot_batch_CIFAR10(x, y)
    break
# Out:
# Running on cpu
